# %%
import numpy as np
import pandas as pd
import pickle
import lhs
import spatial_plot

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
samples = lhs.LatinHypercubeSample(df)
# Out:
# (33820, 12)
# num samples to build: 1000

# %%
df.head()
# Out:
#    elev med    zen  slope  wv range  wv med        lat        lon      date  \
# 0      3.17  49.77   9.00      2.69    0.24  73.462646  21.543773  20220810
# 1      2.75  49.24   3.77      0.16    0.09  73.963529  22.116728  20220810
# 2      2.52  48.71   4.14      0.30    0.12  74.468918  22.687622  20220810
# 3      2.55  48.19   1.84      4.10    0.08  74.978765  23.256703  20220810
# 4      0.96  47.68   2.41      4.99    3.88  75.493399  23.823590  20220810
#
#      time  orbit scene                              fid
# 0  034103  22203   000  emit20220810t034103_o22203_s000
# 1  034115  22203   000  emit20220810t034115_o22203_s000
# 2  034127  22203   000  emit20220810t034127_o22203_s000
# 3  034139  22203   000  emit20220810t034139_o22203_s000
# 4  034151  22203   000  emit20220810t034151_o22203_s000

# %%
lhs_samples = df.iloc[samples]
lhs_fids = lhs_samples['fid']
lhs_samples.head()
# Out:
#        elev med    zen  slope  wv range  wv med        lat        lon  \
# 31490      0.14   4.49   3.16      0.28    1.24  41.842717  24.976532
# 31496      0.04   7.76   3.37      0.22    1.46  44.917804  21.572525
# 32208      0.30  15.10   0.00      0.50    1.31  34.016971  27.816756
# 26291      0.31  28.71   1.98      0.15    0.71  94.772165  40.068684
# 16716      0.06  35.72  10.63      0.31    0.43  19.014992  21.234724
#
#            date    time  orbit scene                              fid
# 31490  20230623  093233  17406   006  emit20230623t093233_o17406_s006
# 31496  20230623  093344  17406   006  emit20230623t093344_o17406_s006
# 32208  20230626  084115  17706   003  emit20230626t084115_o17706_s003
# 26291  20230531  072106  15105   002  emit20230531t072106_o15105_s002
# 16716  20230326  125213  08509   000  emit20230326t125213_o08509_s000

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples, ' Elev Med, Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples, ' Elev Med, Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples2 = lhs.LatinHypercubeSample2(df)
lhs_samples2 = df.iloc[samples2]
lhs_fid2s = lhs_samples2['fid']
lhs_samples2.head()
# Out:
# num samples to build: 1156
#        elev med    zen  slope  wv range  wv med        lat        lon  \
# 31772       0.0   1.51   3.16      0.07    1.60  48.101075  24.881780
# 32016       0.0   4.16   3.53      0.12    1.60  34.582200  20.518584
# 26175       0.0   5.10   4.94      0.11    2.50  -6.483082  18.234054
# 23493       0.0   8.05   2.03      0.16    0.72  -1.171022  16.469982
# 18031       0.0  10.65   2.75      0.11    0.96  -4.502105  13.106097
#
#            date    time  orbit scene                              fid
# 31772  20230624  084456  17506   002  emit20230624t084456_o17506_s002
# 32016  20230625  093133  17606   003  emit20230625t093133_o17606_s003
# 26175  20230530  123909  15009   000  emit20230530t123909_o15009_s000
# 23493  20230427  112930  11707   001  emit20230427t112930_o11707_s001
# 18031  20230331  115950  09008   000  emit20230331t115950_o09008_s000

# %%
lhs_fid2s.shape
# Out:
# (946,)

# %%
lhs_fid2s
# Out:
# 31772    emit20230624t084456_o17506_s002
# 32016    emit20230625t093133_o17606_s003
# 26175    emit20230530t123909_o15009_s000
# 23493    emit20230427t112930_o11707_s001
# 18031    emit20230331t115950_o09008_s000
#                       ...
# 1876     emit20220819t141008_o23109_s000
# 1321     emit20220817t154320_o22910_s000
# 683      emit20220815t110251_o22707_s003
# 256      emit20220813t232605_o22515_s000
# 404      emit20220814t115132_o22608_s001
# Name: fid, Length: 946, dtype: object

# %%
np.savetxt('../FIDs.txt', lhs_fid2s, fmt='%s')

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples2, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples2, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples3 = lhs.LatinHypercubeSample3(df)
lhs_samples3 = df.iloc[samples3]
lhs_fids3 = lhs_samples3['fid']
# Out:
# num samples to build: 900

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples3, ' Elev Med and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples3, ' Elev Med and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples4 = lhs.LatinHypercubeSample4(df)
lhs_samples4 = df.iloc[samples4]
lhs_fids4 = lhs_samples4['fid']
# Out:
# num samples to build: 1000

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples4, ' Elev Med, Slope and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples4, ' Elev Med, Slope and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))
