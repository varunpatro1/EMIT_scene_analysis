# %%
import numpy as np
import pandas as pd
import pickle
from idaes import *
#from smt.sampling_methods import LHS
#from idaes.surrogate.pysmo.sampling import HammersleySampling

#from idaes.surrogate.pysmo.sampling import LatinHypercubeSampling

from idaes.core.surrogate.pysmo.sampling import LatinHypercubeSampling
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
print(df.columns.values)
# Out:
# (33820, 11)
# ['elev med' 'zen' 'slope' 'wv range' 'wv med' 'lat' 'lon' 'date' 'time'
#  'orbit' 'scene']

# %%
df.head()
# Out:
#    elev med    zen  slope  wv range  wv med        lat        lon      date  \
# 0      3.17  49.77   9.00      2.69    0.24  73.462646  21.543773  20220810
# 1      2.75  49.24   3.77      0.16    0.09  73.963529  22.116728  20220810
# 2      2.52  48.71   4.14      0.30    0.12  74.468918  22.687622  20220810
# 3      2.55  48.19   1.84      4.10    0.08  74.978765  23.256703  20220810
# 4      0.96  47.68   2.41      4.99    3.88  75.493399  23.823590  20220810
#
#      time  orbit scene
# 0  034103  22203   000
# 1  034115  22203   000
# 2  034127  22203   000
# 3  034139  22203   000
# 4  034151  22203   000

# %%
lhs = LatinHypercubeSampling(df, 1500, sampling_type="selection", xlabels = ['elev med', 'zen', 'slope', 'wv range', 'wv med'], \
                             ylabels = ['lat', 'lon'])
# Out:
# Sampling type:  selection

# %%
samples = lhs.sample_points()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 samples = lhs.sample_points()
#
# File c:\users\vpatro\desktop\idaes-pse\idaes\core\surrogate\pysmo\sampling.py:683, in LatinHypercubeSampling.sample_points(self)
#     679 vector_of_points = (
#     680     self.lhs_points_generation()
#     681 )  # Assumes [X, Y] data is supplied.
#     682 generated_sample_points = self.random_shuffling(vector_of_points)
# --> 683 unique_sample_points = self.sample_point_selection(
#     684     self.data, generated_sample_points, self.sampling_type
#     685 )
#     687 if len(self.data_headers) > 0 and self.df_flag:
#     688     unique_sample_points = pd.DataFrame(
#     689         unique_sample_points, columns=self.data_headers
#     690     )
#
# File c:\users\vpatro\desktop\idaes-pse\idaes\core\surrogate\pysmo\sampling.py:177, in SamplingMethods.sample_point_selection(self, full_data, sample_points, sampling_type)
#     175 if sampling_type == "selection":
#     176     sd = FeatureScaling()
# --> 177     scaled_data, data_min, data_max = sd.data_scaling_minmax(full_data)
#     178     points_closest_scaled = self.points_selection(scaled_data, sample_points)
#     179     points_closest_unscaled = sd.data_unscaling_minmax(
#     180         points_closest_scaled, data_min, data_max
#     181     )
#
# File c:\users\vpatro\desktop\idaes-pse\idaes\core\surrogate\pysmo\sampling.py:67, in FeatureScaling.data_scaling_minmax(data)
#      65 data_minimum = np.min(input_data, axis=0)
#      66 data_maximum = np.max(input_data, axis=0)
# ---> 67 scale = data_maximum - data_minimum
#      68 scale[scale == 0.0] = 1.0
#      69 scaled_data = (input_data - data_minimum) / scale
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
samples.shape
# Out:
# (766, 7)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7152\2827825508.py in ?()
# ----> 1 index_list = df(df['elev med'] == 0.0 and df['zen'] == 1.94 and df['slope'] == 1.94 and df['wv range'] == 2.33 and df['wv med'] == 5.80).index.tolist()
#
# ~\AppData\Local\anaconda3\envs\coverage_plotting\lib\site-packages\pandas\core\generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
samples.head()
# Out:
#    elev med   zen  slope  wv range  wv med        lat        lon
# 0       0.0  1.26   1.94      2.33    5.80  71.739953  24.830422
# 1       0.0  1.79   5.87      0.54    2.57  48.306513  19.972744
# 2       0.0  2.75   3.62      0.53    4.81  70.676839  25.949266
# 3       0.0  4.22   2.68      0.39    4.13  30.311020  14.191928
# 4       0.0  6.07  15.27      3.42    4.21  65.712440  25.618433

# %%
geometry = [Point(xy) for xy in zip(samples['lat'], samples['lon'])]
gdf = GeoDataFrame(samples, geometry = geometry)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax = world.plot(figsize = (15,15)), marker = 'o', color = 'red', markersize = 3);
# Out:
# C:\Users\vpatro\AppData\Local\Temp\ipykernel_7152\2464672261.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
data_minimum = np.min(df, axis=0)
print(data_minimum)
# Out:
# elev med                                0.0
# zen                                    0.22
# slope                                   0.0
# wv range                                0.0
# wv med                                 0.05
# lat                             -161.449606
# lon                              -51.778556
# fid         emit20220810t034103_o22203_s000
# dtype: object

# %%
row_num = df[df == '35days'].index
# Out:
# elev med    0.00
# zen         1.26
# slope       1.94
# wv range    2.33
# wv med      5.80
# Name: 0, dtype: float64

# %% [markdown]
# xlabels = ['elev med', 'zen', 'slope', 'wv range', 'wv med']
#
# set_of_labels = xlabels
# x_data = data.filter(xlabels).values
# print('x data: ', x_data.shape)
# data_headers = set_of_labels
# print('data headers: ', data_headers)
# data_headers_xvars = xlabels
# print('data headers xvars: ', data_headers_xvars)
# data = data.filter(set_of_labels).values
# print('data: ', data.shape)

# %% [markdown]
# no_y_vars = x_data.shape[1] - data.shape[1]
# print(no_y_vars)
# data[:, :no_y_vars]
# dist = data[:, :no_y_vars] - data[0]

# %% [markdown]
# dist = data - data[0]
# l2_norm = np.sqrt(np.sum((dist**2), axis=1))
# l2_norm = l2_norm.reshape(l2_norm.shape[0], 1)
# distances = np.append(data, l2_norm, 1)
# sorted_distances = distances[distances[:, -1].argsort()]
# closest_point = sorted_distances[0, :-1]
# print(closest_point)

# %%
data[0]
# Out:
# array([ 3.17, 49.77,  9.  ,  2.69,  0.24])

# %%
dist
# Out:
# array([[  0.  ,   0.  ,   0.  ,   0.  ,   0.  ],
#        [ -0.42,  -0.53,  -5.23,  -2.53,  -0.15],
#        [ -0.65,  -1.06,  -4.86,  -2.39,  -0.12],
#        ...,
#        [ -3.17,  -9.3 ,  -7.01,  -0.94,   2.23],
#        [ -2.44, -14.87,  -0.75,   3.26,   2.46],
#        [ -2.34, -14.31,  -6.76,   3.21,   1.7 ]])

# %%
import lhs

# %%
data[:,:-1]
# Out:
# array([[ 3.17, 49.77,  9.  ,  2.69],
#        [ 2.75, 49.24,  3.77,  0.16],
#        [ 2.52, 48.71,  4.14,  0.3 ],
#        ...,
#        [ 0.  , 40.47,  1.99,  1.75],
#        [ 0.73, 34.9 ,  8.25,  5.95],
#        [ 0.83, 35.46,  2.24,  5.9 ]])

# %%
lhs_sampler = lhs.LHS(data, 1000, sampling_type="selection", xlabels = ['elev med', 'zen', 'slope', 'wv range', 'wv med'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 lhs_sampler = lhs.LHS(data, 1000, sampling_type="selection", xlabels = ['elev med', 'zen', 'slope', 'wv range', 'wv med'])
#
# File ~\Desktop\global_coverage\lhs.py:188, in LHS.__init__(self, data_input, number_of_samples, sampling_type, xlabels, ylabels)
#     186 def __init__(self, data_input, number_of_samples=None, sampling_type=None, xlabels=None, ylabels=None):
# --> 188     if self.sampling_type == "selection":
#     189         if isinstance(data_input, (pd.DataFrame, np.ndarray)):
#     190             self.selection_columns_preprocessing(data_input, xlabels, ylabels)
#
# AttributeError: 'LHS' object has no attribute 'sampling_type'

# %%
samples = lhs.sample_points()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 samples = lhs.sample_points()
#
# File ~\AppData\Local\anaconda3\envs\coverage_plotting\lib\site-packages\idaes\core\surrogate\pysmo\sampling.py:681, in LatinHypercubeSampling.sample_points(self)
#     677 vector_of_points = (
#     678     self.lhs_points_generation()
#     679 )  # Assumes [X, Y] data is supplied.
#     680 generated_sample_points = self.random_shuffling(vector_of_points)
# --> 681 unique_sample_points = self.sample_point_selection(
#     682     self.data, generated_sample_points, self.sampling_type
#     683 )
#     685 if len(self.data_headers) > 0 and self.df_flag:
#     686     unique_sample_points = pd.DataFrame(
#     687         unique_sample_points, columns=self.data_headers
#     688     )
#
# File ~\AppData\Local\anaconda3\envs\coverage_plotting\lib\site-packages\idaes\core\surrogate\pysmo\sampling.py:176, in SamplingMethods.sample_point_selection(self, full_data, sample_points, sampling_type)
#     174 sd = FeatureScaling()
#     175 scaled_data, data_min, data_max = sd.data_scaling_minmax(full_data)
# --> 176 points_closest_scaled = self.points_selection(scaled_data, sample_points)
#     177 points_closest_unscaled = sd.data_unscaling_minmax(
#     178     points_closest_scaled, data_min, data_max
#     179 )
#     181 unique_sample_points = np.unique(points_closest_unscaled, axis=0)
#
# File ~\AppData\Local\anaconda3\envs\coverage_plotting\lib\site-packages\idaes\core\surrogate\pysmo\sampling.py:166, in SamplingMethods.points_selection(self, full_data, generated_sample_points)
#     162 equivalent_points = np.zeros(
#     163     (generated_sample_points.shape[0], len(self.data_headers))
#     164 )
#     165 for i in range(0, generated_sample_points.shape[0]):
# --> 166     closest_point = self.nearest_neighbour(
#     167         full_data, generated_sample_points[i, :]
#     168     )
#     169     equivalent_points[i, :] = closest_point
#     170 return equivalent_points
#
# File ~\AppData\Local\anaconda3\envs\coverage_plotting\lib\site-packages\idaes\core\surrogate\pysmo\sampling.py:141, in SamplingMethods.nearest_neighbour(self, full_data, a)
#     123 """
#     124 Function determines the closest point to a in data_input (user provided data).
#     125 This is done by determining the input data with the smallest L2 distance from a.
#    (...)
#     138     closest_point: a row vector containing the closest point to a in self.x_data
#     139 """
#     140 no_y_vars = self.x_data.shape[1] - full_data.shape[1]
# --> 141 dist = full_data[:, :no_y_vars] - a
#     142 l2_norm = np.sqrt(np.sum((dist**2), axis=1))
#     143 l2_norm = l2_norm.reshape(l2_norm.shape[0], 1)
#
# ValueError: operands could not be broadcast together with shapes (33820,0) (5,)
