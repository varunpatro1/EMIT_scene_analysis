# %%
import numpy as np
import pandas as pd
import pickle
import lhs
import spatial_plot

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
samples = lhs.LatinHypercubeSample(df)
# Out:
# (22886, 13)
# num samples to build: 1024

# %%
df.head()
# Out:
#    elev med    zen  slope  wv range  wv med  total cloud fraction        lat  \
# 0      3.22  36.97   7.65      4.78    1.52                  0.10  90.483704
# 1      2.23  36.66   3.77      0.66    1.79                  0.02  91.182553
# 2      2.06  36.37   1.51      0.40    1.71                  0.03  91.891301
# 3      2.08  36.08   2.58      1.04    1.64                  0.03  92.610548
# 4      2.31  35.81  14.88      4.74    1.81                  0.00  93.339586
#
#          lon                              fid      date    time  orbit scene
# 0  37.149964  emit20220810t034648_o22203_s001  20220810  034648  22203   001
# 1  37.631332  emit20220810t034700_o22203_s001  20220810  034700  22203   001
# 2  38.106329  emit20220810t034712_o22203_s001  20220810  034712  22203   001
# 3  38.577816  emit20220810t034724_o22203_s001  20220810  034724  22203   001
# 4  39.044287  emit20220810t034735_o22203_s001  20220810  034735  22203   001

# %%
lhs_samples = df.iloc[samples]
lhs_fids = lhs_samples['fid']
lhs_samples.head()
# Out:
#        elev med    zen  slope  wv range  wv med  total cloud fraction  \
# 17877      0.11   6.65   2.61      0.18    2.44                   0.0
# 15526      0.10   8.42   5.68      0.29    2.32                   0.0
# 20750      0.38  14.00  17.26      0.54    1.48                   0.0
# 21980      0.04  14.70   3.75      0.12    1.23                   0.0
# 11207      0.13  24.27   0.00      0.18    1.34                   0.0
#
#               lat        lon                              fid      date  \
# 17877   41.277834  24.721209  emit20230602t084528_o15306_s002  20230602
# 15526   45.258913  17.400255  emit20230427t082332_o11705_s003  20230427
# 20750  109.233942  37.656295  emit20230621t045143_o17203_s003  20230621
# 21980   45.794385  21.878909  emit20230627t075534_o17805_s002  20230627
# 11207  -17.254856  19.918959  emit20230328t142324_o08710_s000  20230328
#
#          time  orbit scene
# 17877  084528  15306   002
# 15526  082332  11705   003
# 20750  045143  17203   003
# 21980  075534  17805   002
# 11207  142324  08710   000

# %%
lhs_fids.shape
# Out:
# (498,)

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples, ' Elev Med, Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples, ' Elev Med, Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples2 = lhs.LatinHypercubeSample2(df)
lhs_samples_2 = df.iloc[samples2]
lhs_fids_2 = lhs_samples_2['fid']
lhs_samples_2.head()
# Out:
# num samples to build: 972
#        elev med   zen  slope  wv range  wv med  total cloud fraction  \
# 21447       0.0  0.76   1.99      0.06    1.63                  0.43
# 15439       0.0  3.51   2.38      0.21    0.76                  0.00
# 17706       0.0  3.16   6.44      0.24    1.55                  0.00
# 17982       0.0  6.81   5.78      0.30    0.90                  0.00
# 21224       0.2  5.37   3.56      0.30    1.22                  0.00
#
#              lat        lon                              fid      date  \
# 21447  48.624639  24.319058  emit20230624t084508_o17506_s002  20230624
# 15439  -7.381517  16.520796  emit20230426t121709_o11608_s002  20230426
# 17706  32.716377  22.091638  emit20230601t093216_o15207_s000  20230601
# 17982  -3.417167  27.292961  emit20230602t115201_o15308_s000  20230602
# 21224  42.887043  23.849883  emit20230623t093257_o17406_s006  20230623
#
#          time  orbit scene
# 21447  084508  17506   002
# 15439  121709  11608   002
# 17706  093216  15207   000
# 17982  115201  15308   000
# 21224  093257  17406   006

# %%
lhs_samples_2 = lhs_samples_2.iloc[:,:9]
lhs_samples_2.head()
# Out:
#        elev med   zen  slope  wv range  wv med  total cloud fraction  \
# 21447       0.0  0.76   1.99      0.06    1.63                  0.43
# 15439       0.0  3.51   2.38      0.21    0.76                  0.00
# 17706       0.0  3.16   6.44      0.24    1.55                  0.00
# 17982       0.0  6.81   5.78      0.30    0.90                  0.00
# 21224       0.2  5.37   3.56      0.30    1.22                  0.00
#
#              lat        lon                              fid
# 21447  48.624639  24.319058  emit20230624t084508_o17506_s002
# 15439  -7.381517  16.520796  emit20230426t121709_o11608_s002
# 17706  32.716377  22.091638  emit20230601t093216_o15207_s000
# 17982  -3.417167  27.292961  emit20230602t115201_o15308_s000
# 21224  42.887043  23.849883  emit20230623t093257_o17406_s006

# %%
lhs_samples_2.to_pickle("../lhs_743.pkl")

# %%
#np.savetxt('../FIDs_no_clouds.txt', lhs_fids_2, fmt='%s')

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples_2, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples_2, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples3 = lhs.LatinHypercubeSample3(df)
lhs_samples3 = df.iloc[samples3]
lhs_fids3 = lhs_samples3['fid']
# Out:
# num samples to build: 972

# %%
lhs_fids3.shape
# Out:
# (601,)

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples3, ' Elev Med and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples3, ' Elev Med and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
samples4 = lhs.LatinHypercubeSample4(df)
lhs_samples4 = df.iloc[samples4]
lhs_fids4 = lhs_samples4['fid']
# Out:
# num samples to build: 1024

# %%
lhs_fids4.shape
# Out:
# (586,)

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples4, ' Elev Med, Slope and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:36: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples4, ' Elev Med, Slope and Sza')
# Out:
# C:\Users\vpatro\Desktop\global_coverage\spatial_plot.py:50: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))
