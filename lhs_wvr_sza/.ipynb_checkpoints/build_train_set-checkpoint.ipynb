# %%
import numpy as np
import pandas as pd
import pickle
import sys
import os

sys.path.append((os.path.dirname(os.path.realpath('../lhs'))))
sys.path.append((os.path.dirname(os.path.realpath('../spatial_plot'))))

import lhs
import spatial_plot
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
df.head()
# Out:
# (22886, 13)
#    elev med    zen  slope  wv range  wv med  total cloud fraction        lat  \
# 0      3.22  36.97   7.65      4.78    1.52                  0.10  90.483704
# 1      2.23  36.66   3.77      0.66    1.79                  0.02  91.182553
# 2      2.06  36.37   1.51      0.40    1.71                  0.03  91.891301
# 3      2.08  36.08   2.58      1.04    1.64                  0.03  92.610548
# 4      2.31  35.81  14.88      4.74    1.81                  0.00  93.339586
#
#          lon                              fid      date    time  orbit scene
# 0  37.149964  emit20220810t034648_o22203_s001  20220810  034648  22203   001
# 1  37.631332  emit20220810t034700_o22203_s001  20220810  034700  22203   001
# 2  38.106329  emit20220810t034712_o22203_s001  20220810  034712  22203   001
# 3  38.577816  emit20220810t034724_o22203_s001  20220810  034724  22203   001
# 4  39.044287  emit20220810t034735_o22203_s001  20220810  034735  22203   001

# %%
samples = lhs.LatinHypercubeSample_wvr_sza(df, 31, 3)
lhs_samples = df.iloc[samples]
lhs_fids = lhs_samples['fid']
print(lhs_samples.shape)
lhs_samples.head()
# Out:
# (1725, 13)
#        elev med   zen  slope  wv range  wv med  total cloud fraction  \
# 17648       0.0  1.99   2.38      0.17    0.63                  0.00
# 21446       0.0  1.51   3.16      0.07    1.60                  0.03
# 21449       0.0  0.85   4.53      0.05    1.74                  0.00
# 21452       0.0  3.12   5.75      0.03    1.80                  0.00
# 21474       0.0  2.53   1.73      0.16    1.05                  0.00
#
#              lat        lon                              fid      date  \
# 17648   3.017590  22.165056  emit20230531t115248_o15108_s000  20230531
# 21446  48.101075  24.881780  emit20230624t084456_o17506_s002  20230624
# 21449  49.657727  23.187604  emit20230624t084531_o17506_s002  20230624
# 21452  51.171624  21.475216  emit20230624t084607_o17506_s002  20230624
# 21474   0.565166  25.262032  emit20230624t115026_o17508_s001  20230624
#
#          time  orbit scene
# 17648  115248  15108   000
# 21446  084456  17506   002
# 21449  084531  17506   002
# 21452  084607  17506   002
# 21474  115026  17508   001

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\scene_analysis\spatial_plot.py:41: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\scene_analysis\spatial_plot.py:55: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
np.savetxt('../train_sets/FIDs_1725.txt', lhs_fids, fmt='%s')

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
df.head()
# Out:
# (22886, 13)
#    elev med    zen  slope  wv range  wv med  total cloud fraction        lat  \
# 0      3.22  36.97   7.65      4.78    1.52                  0.10  90.483704
# 1      2.23  36.66   3.77      0.66    1.79                  0.02  91.182553
# 2      2.06  36.37   1.51      0.40    1.71                  0.03  91.891301
# 3      2.08  36.08   2.58      1.04    1.64                  0.03  92.610548
# 4      2.31  35.81  14.88      4.74    1.81                  0.00  93.339586
#
#          lon                              fid      date    time  orbit scene
# 0  37.149964  emit20220810t034648_o22203_s001  20220810  034648  22203   001
# 1  37.631332  emit20220810t034700_o22203_s001  20220810  034700  22203   001
# 2  38.106329  emit20220810t034712_o22203_s001  20220810  034712  22203   001
# 3  38.577816  emit20220810t034724_o22203_s001  20220810  034724  22203   001
# 4  39.044287  emit20220810t034735_o22203_s001  20220810  034735  22203   001

# %%
samples = lhs.LatinHypercubeSample_wvr_sza(df, 26, 3)
lhs_samples = df.iloc[samples]
lhs_fids = lhs_samples['fid']
print(lhs_samples.shape)
lhs_samples.head()
# Out:
# (1285, 13)
#        elev med   zen  slope  wv range  wv med  total cloud fraction  \
# 21445       0.0  2.27   3.72      0.13    1.55                   0.0
# 21451       0.0  2.36   4.83      0.04    1.75                   0.0
# 21450       0.0  1.60   5.78      0.03    1.76                   0.0
# 21441       0.0  5.33   1.56      0.09    1.47                   0.0
# 15407       0.0  5.33   5.23      0.01    1.09                   0.0
#
#              lat        lon                              fid      date  \
# 21445  47.572263  25.441904  emit20230624t084444_o17506_s002  20230624
# 21451  50.672760  22.049021  emit20230624t084555_o17506_s002  20230624
# 21450  50.167464  22.619693  emit20230624t084543_o17506_s002  20230624
# 21441  45.400361  27.659231  emit20230624t084357_o17506_s002  20230624
# 15407  14.959932  18.066774  emit20230426t104348_o11607_s002  20230426
#
#          time  orbit scene
# 21445  084444  17506   002
# 21451  084555  17506   002
# 21450  084543  17506   002
# 21441  084357  17506   002
# 15407  104348  11607   002

# %%
spatial_plot.elev_zen_variance_plt(lhs_samples, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\scene_analysis\spatial_plot.py:41: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
spatial_plot.wv_range_med_variance_plt(lhs_samples, ' Sza and WV Range')
# Out:
# C:\Users\vpatro\Desktop\scene_analysis\spatial_plot.py:55: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))

# %%
#np.savetxt('../train_sets/FIDs_1285.txt', lhs_fids, fmt='%s')
