# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('../emit_data')
print(df.shape)
df.head()
# Out:
# (22886, 13)
#    elev med    zen  slope  wv range  wv med  total cloud fraction        lat  \
# 0      3.22  36.97   7.65      4.78    1.52                  0.10  90.483704
# 1      2.23  36.66   3.77      0.66    1.79                  0.02  91.182553
# 2      2.06  36.37   1.51      0.40    1.71                  0.03  91.891301
# 3      2.08  36.08   2.58      1.04    1.64                  0.03  92.610548
# 4      2.31  35.81  14.88      4.74    1.81                  0.00  93.339586
#
#          lon      date    time  orbit scene                              fid
# 0  37.149964  20220810  034648  22203   001  emit20220810t034648_o22203_s001
# 1  37.631332  20220810  034700  22203   001  emit20220810t034700_o22203_s001
# 2  38.106329  20220810  034712  22203   001  emit20220810t034712_o22203_s001
# 3  38.577816  20220810  034724  22203   001  emit20220810t034724_o22203_s001
# 4  39.044287  20220810  034735  22203   001  emit20220810t034735_o22203_s001

# %%
plt.scatter(df['wv med'], df['total cloud fraction'], alpha = 0.2)
plt.xlabel('WV Med')
plt.ylabel('Total Cloud Fraction')
# Out:
# Text(0, 0.5, 'Total Cloud Fraction')
