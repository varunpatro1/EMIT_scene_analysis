# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_pickle('../emit_data')
df = df.iloc[:,:7]
df.head()
# Out:
#    elev med    zen  slope  wv range  wv med        lat        lon
# 0      3.17  49.77   9.00      2.69    0.24  73.462646  21.543773
# 1      2.75  49.24   3.77      0.16    0.09  73.963529  22.116728
# 2      2.52  48.71   4.14      0.30    0.12  74.468918  22.687622
# 3      2.55  48.19   1.84      4.10    0.08  74.978765  23.256703
# 4      0.96  47.68   2.41      4.99    3.88  75.493399  23.823590

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#           elev med       zen     slope  wv range    wv med       lat       lon
# elev med  1.000000  0.090029  0.490509  0.146798 -0.154924 -0.019570  0.040573
# zen       0.090029  1.000000 -0.011359 -0.146097 -0.235862 -0.001835 -0.014117
# slope     0.490509 -0.011359  1.000000  0.072859 -0.013211 -0.007222  0.103328
# wv range  0.146798 -0.146097  0.072859  1.000000  0.526774 -0.000850 -0.197659
# wv med   -0.154924 -0.235862 -0.013211  0.526774  1.000000  0.068214 -0.198345
# lat      -0.019570 -0.001835 -0.007222 -0.000850  0.068214  1.000000  0.087790
# lon       0.040573 -0.014117  0.103328 -0.197659 -0.198345  0.087790  1.000000

# %%
from pandas.plotting import scatter_matrix
attributes = ['elev med', 'zen', 'slope', 'wv range', 'wv med', 'lat', 'lon']
scatter_matrix(df[attributes], figsize = (12, 8))
# Out:
# array([[<Axes: xlabel='elev med', ylabel='elev med'>,
#         <Axes: xlabel='zen', ylabel='elev med'>,
#         <Axes: xlabel='slope', ylabel='elev med'>,
#         <Axes: xlabel='wv range', ylabel='elev med'>,
#         <Axes: xlabel='wv med', ylabel='elev med'>,
#         <Axes: xlabel='lat', ylabel='elev med'>,
#         <Axes: xlabel='lon', ylabel='elev med'>],
#        [<Axes: xlabel='elev med', ylabel='zen'>,
#         <Axes: xlabel='zen', ylabel='zen'>,
#         <Axes: xlabel='slope', ylabel='zen'>,
#         <Axes: xlabel='wv range', ylabel='zen'>,
#         <Axes: xlabel='wv med', ylabel='zen'>,
#         <Axes: xlabel='lat', ylabel='zen'>,
#         <Axes: xlabel='lon', ylabel='zen'>],
#        [<Axes: xlabel='elev med', ylabel='slope'>,
#         <Axes: xlabel='zen', ylabel='slope'>,
#         <Axes: xlabel='slope', ylabel='slope'>,
#         <Axes: xlabel='wv range', ylabel='slope'>,
#         <Axes: xlabel='wv med', ylabel='slope'>,
#         <Axes: xlabel='lat', ylabel='slope'>,
#         <Axes: xlabel='lon', ylabel='slope'>],
#        [<Axes: xlabel='elev med', ylabel='wv range'>,
#         <Axes: xlabel='zen', ylabel='wv range'>,
#         <Axes: xlabel='slope', ylabel='wv range'>,
#         <Axes: xlabel='wv range', ylabel='wv range'>,
#         <Axes: xlabel='wv med', ylabel='wv range'>,
#         <Axes: xlabel='lat', ylabel='wv range'>,
#         <Axes: xlabel='lon', ylabel='wv range'>],
#        [<Axes: xlabel='elev med', ylabel='wv med'>,
#         <Axes: xlabel='zen', ylabel='wv med'>,
#         <Axes: xlabel='slope', ylabel='wv med'>,
#         <Axes: xlabel='wv range', ylabel='wv med'>,
#         <Axes: xlabel='wv med', ylabel='wv med'>,
#         <Axes: xlabel='lat', ylabel='wv med'>,
#         <Axes: xlabel='lon', ylabel='wv med'>],
#        [<Axes: xlabel='elev med', ylabel='lat'>,
#         <Axes: xlabel='zen', ylabel='lat'>,
#         <Axes: xlabel='slope', ylabel='lat'>,
#         <Axes: xlabel='wv range', ylabel='lat'>,
#         <Axes: xlabel='wv med', ylabel='lat'>,
#         <Axes: xlabel='lat', ylabel='lat'>,
#         <Axes: xlabel='lon', ylabel='lat'>],
#        [<Axes: xlabel='elev med', ylabel='lon'>,
#         <Axes: xlabel='zen', ylabel='lon'>,
#         <Axes: xlabel='slope', ylabel='lon'>,
#         <Axes: xlabel='wv range', ylabel='lon'>,
#         <Axes: xlabel='wv med', ylabel='lon'>,
#         <Axes: xlabel='lat', ylabel='lon'>,
#         <Axes: xlabel='lon', ylabel='lon'>]], dtype=object)
